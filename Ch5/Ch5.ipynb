# %% [markdown]
# # Ch5 机器学习的基本思想

# %% [markdown]
# ## $\S5.1$ 欠拟合与过拟合

# %% [markdown]
# ## $\S5.2$ 正则化约束

# %% [markdown]
# ## $\S5.3$ 输入特征与相似度

# %% [markdown]
# ## $\S5.4$ 参数与超参数

# %% [markdown]
# ## $\S5.5$ 数据集划分与交叉验证
